# %% [markdown]
# introduction to pandas

# %%
import pandas as pd

# %% [markdown]
# 8.pannel-3d labeled
#
# data frame- 2d labeled
#
# series- hetarogenous(mutable)
#
# create dataframe-list,series,dict,ndarray,dataframe

# %%
data = {'apple' : [3,2,0,1], 'orange' : [0,3,7,2]}

# %%
df = pd.DataFrame(data)
df
# Out:
#    apple  orange
# 0      3       0
# 1      2       3
# 2      0       7
# 3      1       2

# %%
data = { 'col_1' : [3,2,1,0] ,'col_2' :['a','b','c','d']}
pd.DataFrame.from_dict(data)
# Out:
#    col_1 col_2
# 0      3     a
# 1      2     b
# 2      1     c
# 3      0     d

# %%
data = { 'row_1' : [3,2,1,0] ,'row_2' :['a','b','c','d']}
pd.DataFrame.from_dict(data, orient = 'index')
# Out:
#        0  1  2  3
# row_1  3  2  1  0
# row_2  a  b  c  d

# %%
data = { 'row_1' : [3,2,1,0] ,'row_2' :['a','b','c','d']}
pd.DataFrame.from_dict(data, orient = 'index',columns = ['A','B', 'C','D'])
# Out:
#        A  B  C  D
# row_1  3  2  1  0
# row_2  a  b  c  d

# %% [markdown]
# loading a dataframe from files
# csv.xml,html.json

# %%
df = pd.read_csv("/content/drive/MyDrive/9th /Copy of weather-numeric.csv")

# %%
df
# Out:
#      outlook  temperature  humidity  windy play
# 0      sunny           85        85  False   no
# 1      sunny           80        90   True   no
# 2   overcast           83        86  False  yes
# 3      rainy           70        96  False  yes
# 4      rainy           68        80  False  yes
# 5      rainy           65        70   True   no
# 6   overcast           64        65   True  yes
# 7      sunny           72        95  False   no
# 8      sunny           69        70  False  yes
# 9      rainy           75        80  False  yes
# 10     sunny           75        70   True  yes
# 11  overcast           72        90   True  yes
# 12  overcast           81        75  False  yes
# 13     rainy           71        91   True   no

# %%
df.tail(2)
# Out:
#      outlook  temperature  humidity  windy play
# 12  overcast           81        75  False  yes
# 13     rainy           71        91   True   no

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   outlook      14 non-null     object
#  1   temperature  14 non-null     int64
#  2   humidity     14 non-null     int64
#  3   windy        14 non-null     bool
#  4   play         14 non-null     object
# dtypes: bool(1), int64(2), object(2)
# memory usage: 590.0+ bytes

# %%
df.shape
# Out:
# (14, 5)

# %%
df.head()
# Out:
#     outlook  temperature  humidity  windy play
# 0     sunny           85        85  False   no
# 1     sunny           80        90   True   no
# 2  overcast           83        86  False  yes
# 3     rainy           70        96  False  yes
# 4     rainy           68        80  False  yes

# %% [markdown]
# handling duplicates  values
#
# drop_duplication will drop every duplication

# %%
tep_df = df.append(df)
tep_df.shape
# Out:
# <ipython-input-40-f9a532697e6a>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tep_df = df.append(df)
# (28, 5)

# %%
tep_df = tep_df.drop_duplicates(df)
tep_df.shape
# Out:
# (14, 5)

# %% [markdown]
# describe dataset

# %%
df.describe()
# Out:
#        temperature   humidity
# count    14.000000  14.000000
# mean     73.571429  81.642857
# std       6.571667  10.285218
# min      64.000000  65.000000
# 25%      69.250000  71.250000
# 50%      72.000000  82.500000
# 75%      78.750000  90.000000
# max      85.000000  96.000000

# %%
df['humidity'].describe()
# Out:
# count    14.000000
# mean     81.642857
# std      10.285218
# min      65.000000
# 25%      71.250000
# 50%      82.500000
# 75%      90.000000
# max      96.000000
# Name: humidity, dtype: float64

# %%
data = [1,2,3,10,30]
df =pd.DataFrame(data)
print(df)
# Out:
#     0
# 0   1
# 1   2
# 2   3
# 3  10
# 4  30

# %%
data = {'Name' : ['AA','BB'], 'Age' : [30,45]}
df = pd.DataFrame(data)
print(df)
# Out:
#   Name  Age
# 0   AA   30
# 1   BB   45

# %%
data = { 'Sumu' : ['apple', 'mango','orange',' suuii'],'prantee' : [1,2,3,4], 'mitu' : [5,7,8,9]}
df = pd.DataFrame(data)
print(df)
# Out:
#      Sumu  prantee  mitu
# 0   apple        1     5
# 1   mango        2     7
# 2  orange        3     8
# 3   suuii        4     9

# %%
data = [{'a': 1, 'b' : 2},{'a' : 5, 'b' :10, 'c' :20}]
df = pd.DataFrame(data)
print(df)
# Out:
#    a   b     c
# 0  1   2   NaN
# 1  5  10  20.0

# %%
data = [{'a': 1, 'b' : 2},{'a' : 5, 'b' :10, 'c' :20}]
df = pd.DataFrame(data, index = ['first','second'])
print(df)
# Out:
#         a   b     c
# first   1   2   NaN
# second  5  10  20.0

# %%
data = [{'a' : 1, 'b' : 2}, {'a' : 5, 'b' :10, 'c' :20}]
df1 =pd.DataFrame(data, index = ['first','second'], columns = ['a','b1'])
print(df1)
# Out:
#         a  b1
# first   1 NaN
# second  5 NaN

# %%
data = [{'a' : 1, 'b' : 2}, {'a' : 5, 'b' :10, 'c' :20}]
df1 =pd.DataFrame(data, index = ['first','second'], columns = ['a','b1'])
print(df1)
df2 =pd.DataFrame(data, index = ['first','second'],columns = ['a','b1'])
print ('........')
print(df2)
# Out:
#         a  b1
# first   1 NaN
# second  5 NaN
# ........
#         a  b1
# first   1 NaN
# second  5 NaN
